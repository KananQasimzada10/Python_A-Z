# %%
//end method
print("Hello world")
print("Hello world asdf",end="space")
print("again hello world")

// + method
print("Hello world " + " Salam dunya")

//{} in string
c = 32
d = 33
e = 100
f = 200
print ("c:{} and b:{} {} {}".format(c,d,e,f))

//sep method
c = 32
d = 33
e = 100
f = 200
print (c,d,e,f,sep = '---')


// f method

name = 'Kanan'
age = 19

print(f'Hello my name is {name} and I am {age} old ')

*************************
num1 = 15
num2 = 20
num3 = 25

print(f"total sum of number:{num1 + num2 + num3}")

**************************
//Mixed method

print('G','F', sep='', end='')
print('G')
#\n provides new line after printing the year
print('09','12','2016', sep='-', end='\n')

print('Red','Green','Blue', sep=',', end='@')
print('geeksforgeeks')

**********************************************
//end with number
c = int(input("Enter a number: "))

while c != 0:
    print(c,end = " ")
    c -= 1
Number:5
Conclusion:5 4 3 2 1
